# %%
from astropy.convolution import *
import sys
import os
sys.path.append(os.path.abspath('..'))
# %matplotlib notebook
# utils=os.path.abspath('..')
from utils import *
import time
from KBs import *

convolve_int=lambda a,fir,method:np.around(convolve(a,fir,method)).astype(np.int);
## Using B3/S23 as example

from os import environ
try:
    input_rulestr= environ['input_rulestr']
except:
    input_rulestr='000000000060031c61c67f86a0';
    print('using default rule, B3/S23')
# if not 'input_rulestr' in locals():
#     input_rulestr='000000000060031c61c67f86a0';
# input_rulestr
# CA_sys
HTML(tog)
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# @function
def measure_temperature(sys0=None,hdist=None,*args,**kwargs):
#     varargin = measure_temperature.varargin
#     nargin = measure_temperature.nargin
    sysX=copy.copy(sys0)
    jmax=sysX.N;
    avi=sysX.rdf()
    siz=avi.shape
    siz=(sysX.hmax,)+siz;
    tmp=np.zeros(siz)
    smtmp=np.zeros(siz)

    avc=avi
    i=0
    fir=np.reshape(2 ** (np.arange(0,9)),[1,3,3])
    trans=6
    mtp=0
    stp=0
    while i+1 < sysX.hmax:

        i=i + 1
        avcnew=(sysX.adv(avc,i))
        cavc=convolve_int(avc,fir,'wrap').astype(np.int);
        cavcnew=convolve_int(avcnew,fir,'wrap').astype(np.int);
        idx=np.ravel_multi_index((cavc,cavcnew),[2**9,2**9]);
        tmp[i,:,:,:]=np.expand_dims(hdist.flat[idx],0)
        if i >= trans:
            smtmpnow=np.mean(tmp[i - trans:i,:,:,:],axis=0)
            smtmp[i - trans,:,:,:]=smtmpnow
            if i >= trans + 10:
                mtp=np.mean(smtmpnow.flat)
                stpmat=((smtmp[i - trans,:,:,:] - smtmp[i - trans - trans,:,:,:]))
                a=np.mean(np.abs(stpmat.flat))
                b=abs(np.mean(stpmat.flat))
                stp=a - b
                stp1=np.mean(avcnew.flat)
                stp1=min(stp1,1 - stp1)
        avc=avcnew;
        #     im1=[avc(1,:,:)];
        if mtp < 0.02 and i > 20:
            break
    
    fam_alias=sys0.familyname+'_'+sys0.alias;
# /home/shouldsee/Documents/repos/CA_tfmat/custom_function/measure_temperature.m:55
    # s=sprintf('%s\\t%s\\t%d\\t%f\\t%f\\t%f\\n',fam_alias,num2str(sys0.od),i,mtp,stp,stp1)
    s='{}\t{}\t{:d}\t{:f}\t{:f}\t{:f}\n'.format(fam_alias,sysX.rulestr,i,mtp,stp,stp1)
# /home/shouldsee/Documents/repos/CA_tfmat/custom_function/measure_temperature.m:56
    return s
    
# if __name__ == '__main__':
#     pass

# %%
# #test
# ca1=CA_sys('2dntca',input_rulestr,[600,100,400]);
# ca1.rulestr2alias();
# s=measure_temperature(ca1,hdist);
# output_data=[];

# %%
### Profiling loop
output_data=[];

repeat=2;
ipt_list=[input_rulestr]*repeat;
# for i in range(5):
l_ipt=len(ipt_list)
print('Starting to profile {:d} rules at {:d} replicates,\n totaling {:d} instances'.format(l_ipt,repeat,l_ipt*repeat))

for num,rulestr in enumerate(ipt_list):
    ca1=CA_sys('2dntca',rulestr,[400,100,400]);
    ca1.rulestr2alias();
    s=measure_temperature(ca1,hdist);
    output_data+=[s];
    print('{:d} of {:d}'.format(num,len(ipt_list)))
temp_data=[];
for line in output_data:
    temp_data+=[line.rstrip('\n').split('\t')];
sample_data=np.array(temp_data)
print('data is succesfully generated at {:d} replicates'.format(repeat))
# Out:
# Starting to profile 2 rules at 2 replicates,
#  totaling 4 instances
# 0 of 2
# 1 of 2
# data is succesfully generated at 2 replicates

# %%
print('\n Detail of the input:')
for k,v in ca1.__dict__.items():
    if not callable(v):
#         print(k+str(v).ljust(-10))
        print("{:5} {:<15} {:<10}".format('',k, str(v)))
# Out:
#  Detail of the input:
#       alias           b01ce2c3i2k4ai5i3c4wkyqz5q6a5yk7c4c5e6e8s1c2a3i2ek3n4a3re4i5i2n3cq4w5a3k4kyq5jnr7c5e6ei7e
#       rulestr         1cde2410a7da1cdd2db0b6a937
#       familyname      2dntca
#       N               400
#       dimsiz          [400, 100, 400]
#       siz             (400, 20, 20)
#       hmax            100

# %%
import numpy as np

## TEST sample_data
# sample_data=np.array([['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.148772', '0.087523',
#         '0.089563'],
#        ['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.152794', '0.086693',
#         '0.091644'],
#        ['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.148733', '0.089657',
#         '0.089387'],
#        ['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.150105', '0.092000',
#         '0.090981'],
#        ['2dntca_b3ianjrecqyks2ac3i2e3a2k3nj2i3re2n3cqyk',
#         '000000000060031c61c67f86a0', '99', '0.153150', '0.089772',
#         '0.090938']], 
#       dtype='<U46')

# %% [markdown]
# ## Landscape of the observed dynamics
# * Hover on the point to get the NTCA(non-totalistic cellular automata) rule-string. Click to display the rulestring as a copyable string.
# * Click on the bottom-left widgets to Zoom-and-pan

# %%
# %matplotlib inline
# mpld3.enable_notebook()
from graphics import *
fig, ax = plt.subplots(subplot_kw=dict(axisbg='#DDDDDD'
#                                        ,projection='3d'
                                      ))
fig.set_size_inches([8,4])
ax.grid(color='white', linestyle='solid')
ax.set_ylim(0,0.38)
ax.set_xlim(0,1)

fig2,ax2=plt.subplots(subplot_kw=dict(axisbg='#DDDDDD'
                                       ,projection='3d'
                                      ))
fig2.set_size_inches([12,12])
# fig2.subplots_adjust(left=0.2, right=0.8, top=0.9, bottom=0.3)

ax2.grid(color='white', linestyle='solid')
ax2.set_ylim(0,0.38)
ax2.set_xlim(0,1)

make_figure((fig,ax,fig2,ax2),sample_data)
mpld3.display(fig)
# Out:
# /home/shouldsee/.local/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# <style>
#
# </style>
#
# <div id="fig_el10671398293285956003650391975"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("clickinfo", ClickInfo);
#     ClickInfo.prototype = Object.create(mpld3.Plugin.prototype);
#     ClickInfo.prototype.constructor = ClickInfo;
#     ClickInfo.prototype.requiredProps = ["id","labels"];
#     function ClickInfo(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     ClickInfo.prototype.draw = function(){
#         var obj = mpld3.get_element(this.props.id);
#         var labels = (this.props.labels);
#         obj.elements().on("mousedown",
#                           function(d, i){
#                           txt=labels[i];
#                           window.prompt("You clicked Point "+ i + ", Ctrl+C to copy to clipboard, Rulestring:", txt);
#
#
#                           });
#     }
#
#        mpld3.draw_figure("fig_el10671398293285956003650391975", {"data": {"data03": [[0.6102150537634409, 0.9218175128771156, 0.8486651490066226, 0.7755127851361294, 0.7065282376747608, 0.6375436902133922], [0.681899641577061, 0.9218175128771156, 0.8486651490066226, 0.7755127851361294, 0.7065282376747608, 0.6375436902133922], [0.681899641577061, 0.954010301692421, 0.880857937821928, 0.8077055739514348, 0.7387210264900662, 0.6697364790286976], [0.6102150537634409, 0.954010301692421, 0.880857937821928, 0.8077055739514348, 0.7387210264900662, 0.6697364790286976]], "data01": [[0.0, 0.0]], "data04": [[0.6030465949820789, 0.6099498712288447], [0.974910394265233, 0.6099498712288447], [0.982078853046595, 0.6099498712288447], [0.982078853046595, 0.6191478108903605], [0.982078853046595, 0.9678072111846947], [0.982078853046595, 0.9770051508462105], [0.974910394265233, 0.9770051508462105], [0.6030465949820789, 0.9770051508462105], [0.5958781362007168, 0.9770051508462105], [0.5958781362007168, 0.9678072111846947], [0.5958781362007168, 0.6191478108903605], [0.5958781362007168, 0.6099498712288447], [0.6030465949820789, 0.6099498712288447]], "data02": [[0.321636, 0.14867], [0.019919, 0.002572], [0.022815, 0.00557], [0.417415, 0.098694], [0.084043, 0.036189], [0.316082, 0.144094], [0.016928, 0.002308], [0.023104, 0.004945], [0.430551, 0.101365], [0.074235, 0.033086], [0.185792, 0.119161], [0.253568, 0.13943], [0.020131, 0.01066], [0.101852, 0.032517], [0.023084, 0.000618], [0.340072, 0.15847], [0.0199, 0.0101], [0.550777, 0.133415], [0.554252, 0.147002], [0.034876, 0.020657], [0.489023, 0.143845], [0.39422, 0.167817], [0.032118, 0.005496], [0.076012, 0.027663], [0.068578, 0.014057], [0.215438, 0.083427], [0.072518, 0.03355], [0.019017, 0.003947], [0.493316, 0.215395], [0.042749, 0.010969], [0.106887, 0.039119], [0.018284, 0.00198], [0.743704, 0.102004], [0.741217, 0.100491]]}, "id": "el1067139829328595600", "height": 288.0, "axes": [{"yscale": "linear", "sharex": [], "xlim": [0.0, 1.0], "zoomable": true, "id": "el1067139829325709888", "paths": [{"dasharray": "none", "yindex": 1, "zorder": 2000001.0, "edgewidth": 1.0, "xindex": 0, "alpha": 0.5, "pathcodes": ["M", "L", "L", "L", "Z"], "data": "data03", "edgecolor": "none", "id": "el1067139829325057048", "facecolor": "#008000", "coordinates": "axes"}, {"dasharray": "none", "yindex": 2, "zorder": 2000001.0, "edgewidth": 1.0, "xindex": 0, "alpha": 0.5, "pathcodes": ["M", "L", "L", "L", "Z"], "data": "data03", "edgecolor": "none", "id": "el1067139829325087184", "facecolor": "#FFFF00", "coordinates": "axes"}, {"dasharray": "none", "yindex": 3, "zorder": 2000001.0, "edgewidth": 1.0, "xindex": 0, "alpha": 0.2, "pathcodes": ["M", "L", "L", "L", "Z"], "data": "data03", "edgecolor": "none", "id": "el1067139829325088696", "facecolor": "#FF0000", "coordinates": "axes"}, {"dasharray": "none", "yindex": 4, "zorder": 2000001.0, "edgewidth": 1.0, "xindex": 0, "alpha": 1, "pathcodes": ["M", "L", "L", "L", "Z"], "data": "data03", "edgecolor": "#FF0F07", "id": "el1067139829325090376", "facecolor": "#FF0F07", "coordinates": "axes"}, {"dasharray": "none", "yindex": 5, "zorder": 2000001.0, "edgewidth": 1.0, "xindex": 0, "alpha": 1, "pathcodes": ["M", "L", "L", "L", "Z"], "data": "data03", "edgecolor": "#750FFE", "id": "el1067139829325112768", "facecolor": "#750FFE", "coordinates": "axes"}, {"dasharray": "none", "yindex": 1, "zorder": 1999999.0, "edgewidth": 1.0, "xindex": 0, "alpha": 0.8, "pathcodes": ["M", "L", "S", "L", "S", "L", "S", "L", "S", "Z"], "data": "data04", "edgecolor": "#CCCCCC", "id": "el1067139829325055144", "facecolor": "#FFFFFF", "coordinates": "axes"}], "axesbgalpha": null, "collections": [{"yindex": 1, "pathcoordinates": "data", "zorder": 1, "offsetcoordinates": "display", "offsets": "data01", "pathtransforms": [], "xindex": 0, "edgecolors": [], "alphas": [0.5], "id": "el1067139830470503616", "paths": [[[[0.12, 0.07500000000000001], [0.12, 0.125], [0.4, 0.215], [0.4, 0.165], [0.4, 0.165], [0.12, 0 ...

# %%
# len(ntca_list)
# .shape
# print(tst_data)

# %%
# from nbconvert import HTMLExporter
# import codecs
# import nbformat
# exporter = HTMLExporter()
# # execfile()
# output_notebook = nbformat.read('calc_temp.ipynb', as_version=4)
# output, resources = exporter.from_notebook_node(output_notebook)
# codecs.open('test.html', 'w', encoding='utf-8').write(output)
